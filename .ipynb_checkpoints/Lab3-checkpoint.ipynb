# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline
# import missingno as mn


df = pd.read_csv('dataset.csv')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
print(df.dtypes)
print('===========')
print(df.info())
# Out:
# Marital status                                      int64
# Application mode                                    int64
# Application order                                   int64
# Course                                              int64
# Daytime/evening attendance                          int64
# Previous qualification                              int64
# Nacionality                                         int64
# Mother's qualification                              int64
# Father's qualification                              int64
# Mother's occupation                                 int64
# Father's occupation                                 int64
# Displaced                                           int64
# Educational special needs                           int64
# Debtor                                              int64
# Tuition fees up to date                             int64
# Gender                                              int64
# Scholarship holder                                  int64
# Age at enrollment                                   int64
# International                                       int64
# Curricular units 1st sem (credited)                 int64
# Curricular units 1st sem (enrolled)                 int64
# Curricular units 1st sem (evaluations)              int64
# Curricular units 1st sem (approved)                 int64
# Curricular units 1st sem (grade)                  float64
# Curricular units 1st sem (without evaluations)      int64
# Curricular units 2nd sem (credited)                 int64
# Curricular units 2nd sem (enrolled)                 int64
# Curricular units 2nd sem (evaluations)              int64
# Curricular units 2nd sem (approved)                 int64
# Curricular units 2nd sem (grade)                  float64
# Curricular units 2nd sem (without evaluations)      int64
# Unemployment rate                                 float64
# Inflation rate                                    float64
# GDP                                               float64
# Target                                             object
# dtype: object
# ===========
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
#  9   Mother's occupation                             4424 non-null   int64
#  10  Father's occupation                             4424 non-null   int64
#  11  Displaced                                       4424 non-null   int64
#  12  Educational special needs                       4424 non-null   int64
#  13  Debtor                                          4424 non-null   int64
#  14  Tuition fees up to date                         4424 non-null   int64
#  15  Gender                                          4424 non-null   int64
#  16  Scholarship holder                              4424 non-null   int64
#  17  Age at enrollment                               4424 non-null   int64
#  18  International                                   4424 non-null   int64
#  19  Curricular units 1st sem (credited)             4424 non-null   int64
#  20  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  21  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  22  Curricular units 1st sem (approved)             4424 non-null   int64
#  23  Curricular units 1st sem (grade)                4424 non-null   float64
#  24  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  25  Curricular units 2nd sem (credited)             4424 non-null   int64
#  26  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  27  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  28  Curricular units 2nd sem (approved)             4424 non-null   int64
#  29  Curricular units 2nd sem (grade)                4424 non-null   float64
#  30  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  31  Unemployment rate                               4424 non-null   float64
#  32  Inflation rate                                  4424 non-null   float64
#  33  GDP                                             4424 non-null   float64
#  34  Target                                          4424 non-null   object
# dtypes: float64(5), int64(29), object(1)
# memory usage: 1.2+ MB
# None

# %% [markdown]
# # Fields to be removed
#
# Marital Status
# Application Mode
# Previous Qualifications
# Nacionality
# Mother's qualification
# Father's qualification
# Mother's occupation
# Father's occupation
# Educational Special Needs
# Age at enrollment
# Curricular units 1st sem (evaluations)
# Curricular units 1st sem (approved)
# Curricular units 1st sem (without evaluations)
# Curricular units 2nd sem (evaluations)
# Curricular units 2nd sem (approved)
# Curricular units 2nd sem (without evaluations)
# Inflation rate
# GDP

# %%
columns_to_remove = [
    'Marital status', 'Application mode', 'Previous qualification', 'Nacionality',
    "Mother's qualification", "Father's qualification", "Mother's occupation",
    "Father's occupation", 'Educational special needs', 'Age at enrollment',
    'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)',
    'Curricular units 1st sem (without evaluations)', 
    'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (approved)',
    'Curricular units 2nd sem (without evaluations)', 'Inflation rate', 'GDP'
]

df.drop(columns=columns_to_remove, inplace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Application order                    4424 non-null   int64
#  1   Course                               4424 non-null   int64
#  2   Daytime/evening attendance           4424 non-null   int64
#  3   Displaced                            4424 non-null   int64
#  4   Debtor                               4424 non-null   int64
#  5   Tuition fees up to date              4424 non-null   int64
#  6   Gender                               4424 non-null   int64
#  7   Scholarship holder                   4424 non-null   int64
#  8   International                        4424 non-null   int64
#  9   Curricular units 1st sem (credited)  4424 non-null   int64
#  10  Curricular units 1st sem (enrolled)  4424 non-null   int64
#  11  Curricular units 1st sem (grade)     4424 non-null   float64
#  12  Curricular units 2nd sem (credited)  4424 non-null   int64
#  13  Curricular units 2nd sem (enrolled)  4424 non-null   int64
#  14  Curricular units 2nd sem (grade)     4424 non-null   float64
#  15  Unemployment rate                    4424 non-null   float64
#  16  Target                               4424 non-null   object
# dtypes: float64(3), int64(13), object(1)
# memory usage: 587.7+ KB
# None

# %%
# the percentage of individuals that droped out of school
sum(df.Target=="Dropout")/len(df)*100.0
# Out:
# 32.120253164556964

# %%
gender_map = {0: 'female', 1: 'male'}

df_grouped = df.groupby(by='Gender')
for val,grp in df_grouped:
    gender = gender_map.get(val, 'Unknown')
    print(f'There are {len(grp)} {gender}s in the data set.')
# Out:
# There are 2868 females in the data set.
# There are 1556 males in the data set.

# %%
dropout_counts = df_grouped['Target'].apply(lambda x: (x == 'Dropout').sum())

# Print the results
for val, count in dropout_counts.items():
    gender = gender_map.get(val, 'Unknown')  # this allows me to make 0 = females and 1 = males 
    print(f'There are {count} {gender}s that dropped out.')
# Out:
# There are 720 females that dropped out.
# There are 701 males that dropped out.

# %%
total_counts = df_grouped.size()
for val in dropout_counts.index:
    gender = gender_map.get(val, 'Unknown')
    total = total_counts[val]
    dropouts = dropout_counts[val]
    percentage = (dropouts / total) * 100
    
    print(f'There are {dropouts} {gender}s that dropped out')
    print(f'This is {percentage:.2f}% of the total {gender}s.\n')
# Out:
# There are 720 females that dropped out
# This is 25.10% of the total females.
#
# There are 701 males that dropped out
# This is 45.05% of the total males.

# %%
import matplotlib.pyplot as plt

# Calculate the number of graduates 
graduated_counts = df_grouped['Target'].apply(lambda x: (x != 'Dropout').sum())

# Create the bar plot for both dropouts and non-dropouts
plt.figure(figsize=(10, 6))

# Plot the bars on the histogram 
plt.bar(index, dropout_counts, bar_width, label='Dropouts', color='red')
plt.bar([i + bar_width for i in index], graduated_counts, bar_width, label='Graduate or Currently Enrolled', color='green')

# Add labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Dropouts vs. Graduates or Enrolled by Gender')
plt.xticks([i + bar_width / 2 for i in index], genders)  # this puts the male and female on x axis 
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Filter the DataFrame for scholarship holders who dropped out and those that didn't 
debtors_dropout = df[(df['Debtor'] == 1) & (df['Target'] == 'Dropout')]
debtors_non_dropout = df[(df['Debtor'] == 1) & (df['Target'] != 'Dropout')]

# Filter the DataFrame for scholarship holders who dropped out and those that didn't 
scholarship_dropout = df[(df['Scholarship holder'] == 1) & (df['Target'] == 'Dropout')]
scholarship_non_dropout = df[(df['Scholarship holder'] == 1) & (df['Target'] != 'Dropout')]

# Create the data for the histogram
labels = ['Debtors', 'Scholarship Holders']
dropout_counts = [len(debtors_dropout), len(scholarship_dropout)]
non_dropout_counts = [len(debtors_non_dropout), len(scholarship_non_dropout)]

# Set the bar width for side-by-side bars
bar_width = 0.35
index = range(len(labels))

# Create the plot
plt.figure(figsize=(7, 4))

# Plot dropouts
plt.bar(index, dropout_counts, bar_width, label='Dropouts', color='red')

# Plot non-dropouts next to them
plt.bar([i + bar_width for i in index], non_dropout_counts, bar_width, label='Non-Dropouts', color='green')

# Add title and labels
plt.title('Dropouts vs Non-Dropouts for Debtors and Scholarship Holders')
plt.xlabel('Category')
plt.ylabel('Number of People')

# Adjust x-ticks to be centered between the bars
plt.xticks([i + bar_width / 2 for i in index], labels)

# Add legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by 'Course' and count the number of dropouts ('Dropout' in 'Target')
course_dropout = df[df['Target'] == 'Dropout'].groupby('Course').size()

# Group the data by 'Course' and count the total number of students in each course
course_total = df.groupby('Course').size()

# Calculate dropout rate (dropouts / total) for each course
dropout_rate = (course_dropout / course_total) * 100

# Fill NaN values with 0 (for courses with no dropouts)
dropout_rate = dropout_rate.fillna(0)

# Plot the dropout rate by course
plt.figure(figsize=(8, 4))
dropout_rate.plot(kind='bar', color='orange')

# Add labels and title
plt.title('Dropout Rate by Course')
plt.xlabel('Course')
plt.ylabel('Dropout Rate (%)')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure with two subplots (1 row, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(10, 5))  # 1 row, 2 columns for side-by-side plots

# Box plot on the first subplot
sns.boxplot(x='Target', y='Curricular units 1st sem (grade)', data=df, ax=axes[0])
axes[0].set_title('Grades (1st Semester) vs Dropout Status (Box Plot)')
axes[0].set_xlabel('Dropout Status')
axes[0].set_ylabel('Grades (1st Semester)')

# Violin plot on the second subplot
sns.violinplot(x='Target', y='Curricular units 1st sem (grade)', data=df, ax=axes[1])
axes[1].set_title('Grades (1st Semester) vs Dropout Status (Violin Plot)')
axes[1].set_xlabel('Dropout Status')
axes[1].set_ylabel('Grades (1st Semester)')

# Display the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter for students who dropped out
df_dropout = df[df['Target'] == 'Dropout']

# Create a count plot for day/night classes among dropouts
plt.figure(figsize=(8, 6))
sns.countplot(x='Daytime/evening attendance', data=df_dropout)

# Add labels and title
plt.title('Day vs Night Classes for Dropout Students')
plt.xlabel('Day/Night Class (0 = Day, 2 = Night)')
plt.ylabel('Number of Students')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter students who dropped out and have 1st semester grades higher than 13
df_dropout_high_grades = df[(df['Target'] == 'Dropout') & (df['Curricular units 1st sem (grade)'] > 13)]

# Group 1: Students who are either debtors or displaced
debtors_or_displaced_count = df_dropout_high_grades[(df_dropout_high_grades['Debtor'] == 1) | 
                                                    (df_dropout_high_grades['Displaced'] == 1)].shape[0]

# Group 2: Students who are neither debtors nor displaced
neither_debtors_nor_displaced_count = df_dropout_high_grades[(df_dropout_high_grades['Debtor'] == 0) & 
                                                             (df_dropout_high_grades['Displaced'] == 0)].shape[0]

# Prepare the data for plotting
labels = ['Debtors or Displaced', 'Neither Debtors nor Displaced']
counts = [debtors_or_displaced_count, neither_debtors_nor_displaced_count]

# Create the histogram
plt.figure(figsize=(6, 4))
plt.bar(labels, counts, color=['blue', 'orange'])

# Add labels and title
plt.title('Comparison of Dropout Students with Grades > 13: Debtors/Displaced vs Neither')
plt.ylabel('Number of Students')
plt.xlabel('Category')

# Show the plot
plt.tight_layout()
plt.show()
